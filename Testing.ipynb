# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    'dataset/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 209 files belonging to 21 classes.

# %%
cnn = tf.keras.models.load_model('Fruits_Vegetables.h5')

# %%
import cv2
image_path = 'dataset/test/banana/Image_4.jpg'
img = cv2.imread(image_path)
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr]) 
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
print(predictions)
# Out:
# [[1.7497251e-17 1.0000000e+00 3.4581055e-26 1.0059311e-21 9.7095203e-20
#   3.9826669e-20 8.2117802e-19 4.2635092e-22 2.2096113e-14 2.3765564e-14
#   5.8002290e-13 7.2122165e-12 7.1793344e-15 1.4737307e-10 2.4416638e-14
#   2.4214042e-12 8.1132266e-20 1.5553822e-18 1.5520552e-13 6.8509488e-26
#   2.8485073e-22]]

# %%
result_index = np.where(predictions[0] == max(predictions[0]))
print(result_index)
# Out:
# (array([1], dtype=int64),)

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("It's a {}".format(test_set.class_names[result_index[0][0]]))
# Out:
# It's a banana
